# %% [markdown]
# **SCATTER PLOTS**

# %%
# Plottng
import matplotlib.pyplot as plt

# Data manipulation
import numpy as np

# Machine learning
from sklearn import datasets

# %% [markdown]
# *Resources:*
#
# matplotlib.pyplot.scatter
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html
#
# Scatter Plot Example
#
# https://matplotlib.org/stable/gallery/shapes_and_collections/scatter.html

# %% [markdown]
# **PAIRS OF FEATURES**

# %%
# https://scikit-learn.org/stable/datasets/toy_dataset.html
diabetes = datasets.load_diabetes()

# Show
diabetes.data
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]], shape=(442, 10))

# %%
# https://scikit-learn.org/stable/datasets/toy_dataset.html
diabetes = datasets.load_diabetes()

# Show
diabetes.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
# https://scikit-learn.org/stable/datasets/toy_dataset.html
diabetes = datasets.load_diabetes()

# Show
diabetes.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
# Data
diabetes.data
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]], shape=(442, 10))

# %%
# Blood pressure
bp = diabetes.data[:, 3] # The same as: [0:len(data), 3] The column at index 3 (the fourth column)

# Show first ten
bp[:10]
# Out:
# array([ 0.02187239, -0.02632753, -0.00567042, -0.03665608,  0.02187239,
#        -0.01944183, -0.01599898,  0.06662945, -0.04009893, -0.03321323])

# %%
# BMI
bmi = diabetes.data[:, 2]

# Show first ten
bmi[:10] # The first ten values
# Out:
# array([ 0.06169621, -0.05147406,  0.04445121, -0.01159501, -0.03638469,
#        -0.04069594, -0.04716281, -0.00189471,  0.06169621,  0.03906215])

# %% [markdown]
# **RELATIONSHIPS**

# %%
# Create a figure and an axis
fig, ax = plt.subplots()

# Scatter plot
ax.scatter(bmi, bp)

# Labels
ax.set_xlabel('BMI')
ax.set_ylabel('Blood Pressure')
# Out:
# Text(0, 0.5, 'Blood Pressure')

# %% [markdown]
# A positive linear relationship between the variables (contrary to the inverse linear relationship)

# %% [markdown]
# **COLOURS**

# %%
# Sex
sex = diabetes.data[:, 1]

# Show first ten
sex[:10]
# Out:
# array([ 0.05068012, -0.04464164,  0.05068012, -0.04464164, -0.04464164,
#        -0.04464164,  0.05068012,  0.05068012,  0.05068012, -0.04464164])

# %%
# Unique sex values
np.unique(sex)
# Out:
# array([-0.04464164,  0.05068012])

# %%
# Create a figure and an axis
fig, ax = plt.subplots()

# Scatter plot
# Change marker:
# https://matplotlib.org/stable/api/markers_api.html#module-matplotlib.markers
ax.scatter(bmi, bp, marker = '.') # better resolution

# Labels
ax.set_xlabel('BMI')
ax.set_ylabel('Blood Pressure')
# Out:
# Text(0, 0.5, 'Blood Pressure')

# %%
# Create a figure and an axis
fig, ax = plt.subplots()

# Scatter plot
# Change colour
ax.scatter(bmi, bp, c = sex, marker = '.')

# Labels
ax.set_xlabel('BMI')
ax.set_ylabel('Blood Pressure')
# Out:
# Text(0, 0.5, 'Blood Pressure')
