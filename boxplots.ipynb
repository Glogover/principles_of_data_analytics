# %% [markdown]
# **BOXPLOTS**

# %%
# Plotting.
import matplotlib.pyplot as plt

# Numerical arrays.
import numpy as np

# %% [markdown]
# **Continuous vs Discrete**

# %%
plt.bar # bar plot
# Out:
# <function matplotlib.pyplot.bar(x: 'float | ArrayLike', height: 'float | ArrayLike', width: 'float | ArrayLike' = 0.8, bottom: 'float | ArrayLike | None' = None, *, align: "Literal['center', 'edge']" = 'center', data=None, **kwargs) -> 'BarContainer'>

# %%
fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]

plt.bar(fruits, counts)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# **CREATING DATA**

# %%
# Random number generator.
rng = np.random.default_rng(12345)

# Show
rng
# Out:
# Generator(PCG64) at 0x711355F6E7A0

# %% [markdown]
# **GENERATING SOME RANDOM NORMAL DATA**

# %%
# GROUP 1: Mean = 75, Std Dev = 10, Size = 3000
group_1 = rng.normal(75, 10, 3000)

# Show
print(group_1)
# Out:
# [60.76174964 87.63728458 66.29338262 ... 68.12764009 66.40789893
#  79.7387807 ]

# %% [markdown]
# **Bar Charts vs Histograms**

# %%
# List of unique values and their counts
unique, counts = np.unique(group_1, return_counts=True)

# Show
unique, counts
# Out:
# (array([ 43.80391374,  44.17871771,  46.39452435, ..., 108.7887608 ,
#         109.61975812, 112.21097811], shape=(3000,)),
#  array([1, 1, 1, ..., 1, 1, 1], shape=(3000,)))

# %%
plt.bar(unique, counts)
# Out:
# <BarContainer object of 3000 artists>

# %%
# Histogram
plt.hist(group_1, bins = 30, edgecolor = 'black')
# Out:
# (array([  2.,   7.,  15.,  26.,  30.,  47.,  67.,  98., 128., 156., 217.,
#         211., 279., 301., 268., 240., 222., 178., 152., 120.,  70.,  73.,
#          40.,  23.,  13.,   6.,   3.,   5.,   2.,   1.]),
#  array([ 43.80391374,  46.08414922,  48.3643847 ,  50.64462018,
#          52.92485566,  55.20509114,  57.48532661,  59.76556209,
#          62.04579757,  64.32603305,  66.60626853,  68.88650401,
#          71.16673949,  73.44697497,  75.72721045,  78.00744593,
#          80.28768141,  82.56791688,  84.84815236,  87.12838784,
#          89.40862332,  91.6888588 ,  93.96909428,  96.24932976,
#          98.52956524, 100.80980072, 103.0900362 , 105.37027168,
#         107.65050716, 109.93074263, 112.21097811]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# **MORE GROUPS**

# %%
# GROUP 2: Mean = 65, Std Dev = 12, Size = 3000
group_2 = rng.normal(65, 12, 3000)

# Show
print(group_2)
# Out:
# [72.09534714 43.20266644 59.27975818 ... 77.63509745 79.85864674
#  60.44774888]

# %%
# GROUP 3: Mean = 85, Std Dev = 8, Size = 3000
group_3 = rng.normal(85, 8, 3000)

# Show
print(group_3)
# Out:
# [84.83906199 80.96252099 82.23468393 ... 80.41947554 83.80021488
#  81.20220214]

# %%
# Histograms
plt.hist(group_1, edgecolor = 'black', label ='Group 1', alpha = 0.5) # alpha = transparency
plt.hist(group_2, edgecolor = 'black', label ='Group 2', alpha = 0.5)
plt.hist(group_3, edgecolor = 'black', label ='Group 3', alpha = 0.5)
plt.legend()
